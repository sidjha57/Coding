# %%
# SS Tutorial 2
# Siddharth Jha
# E1910022 


import numpy as np
import matplotlib.pyplot as plt


#Q2
#i
n = np.arange(0,0.01,0.001)
y = np.sin (200*np.pi*n)
plt.stem(n,y)
# Out:
# <StemContainer object of 3 artists>

# %%
#ii
n = np.arange(0,0.1,0.0025) 
y = np.sin(np.pi*n*200)
plt.stem(n,y)
# Out:
# <StemContainer object of 3 artists>

# %%
#iii
n = np.arange(0,0.1,0.001) 
y = np.sin(np.pi*n*200)
plt.stem(n,y)
# Out:
# <StemContainer object of 3 artists>

# %%
#iv
n = np.arange(0,1,0.1) 
y = np.sin(np.pi*n*200)
plt.stem(n,y)
# Out:
# <StemContainer object of 3 artists>
